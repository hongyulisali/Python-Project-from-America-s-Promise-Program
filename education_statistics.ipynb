# %%
#AVG_MATH_4_SCORE: The state's average score for fourth graders taking the NAEP math exam.
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
file = "education_states.csv"
df= pd.read_csv(file)

# %%
df.head()
# Out:
#         STATE  YEAR  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0     ALABAMA  1992        2678885           304177        1659028
# 1      ALASKA  1992        1049591           106780         720711
# 2     ARIZONA  1992        3258079           297888        1369815
# 3    ARKANSAS  1992        1711959           178571         958785
# 4  CALIFORNIA  1992       26260025          2072470       16546514
#
#    LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0         715680            2653798                  1481703
# 1         222100             972488                   498362
# 2        1590376            3401580                  1435908
# 3         574603            1743022                   964323
# 4        7641041           27138832                 14358922
#
#    SUPPORT_SERVICES_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE  GRADES_ALL_G  \
# 0                        735036                      174053      731634.0
# ...

# %%
len(df)
# Out:
# 510

# %%
df.shape
# Out:
# (510, 12)

# %%
df.dtypes
# Out:
# STATE                            object
# YEAR                              int64
# TOTAL_REVENUE                     int64
# FEDERAL_REVENUE                   int64
# STATE_REVENUE                     int64
# LOCAL_REVENUE                     int64
# TOTAL_EXPENDITURE                 int64
# INSTRUCTION_EXPENDITURE           int64
# SUPPORT_SERVICES_EXPENDITURE      int64
# CAPITAL_OUTLAY_EXPENDITURE        int64
# GRADES_ALL_G                    float64
# AVG_MATH_4_SCORE                float64
# dtype: object

# %%
df.count()
# Out:
# STATE                           510
# YEAR                            510
# TOTAL_REVENUE                   510
# FEDERAL_REVENUE                 510
# STATE_REVENUE                   510
# LOCAL_REVENUE                   510
# TOTAL_EXPENDITURE               510
# INSTRUCTION_EXPENDITURE         510
# SUPPORT_SERVICES_EXPENDITURE    510
# CAPITAL_OUTLAY_EXPENDITURE      510
# GRADES_ALL_G                    400
# AVG_MATH_4_SCORE                484
# dtype: int64

# %%
grouped = df.groupby(['YEAR'])

# %%
grouped.head()
# Out:
#           STATE  YEAR  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 0       ALABAMA  1992        2678885           304177        1659028
# 1        ALASKA  1992        1049591           106780         720711
# 2       ARIZONA  1992        3258079           297888        1369815
# 3      ARKANSAS  1992        1711959           178571         958785
# 4    CALIFORNIA  1992       26260025          2072470       16546514
# 51      ALABAMA  1996        3365113           334858        2138717
# 52       ALASKA  1996        1120346           123505         706116
# 53      ARIZONA  1996        4143304           378917        1798363
# 54     ARKANSAS  1996        2183384           192152        1296247
# 55   CALIFORNIA  1996       31282981          2603882       17061474
# 102     ALABAMA  2000        4885917           425978        3003814
# 103      ALASKA  2000        1313510           199520         774194
# 104     ARIZONA  2000        5479168           534619        2481089
# ...

# %%
df.isnull().sum()
# Out:
# STATE                             0
# YEAR                              0
# TOTAL_REVENUE                     0
# FEDERAL_REVENUE                   0
# STATE_REVENUE                     0
# LOCAL_REVENUE                     0
# TOTAL_EXPENDITURE                 0
# INSTRUCTION_EXPENDITURE           0
# SUPPORT_SERVICES_EXPENDITURE      0
# CAPITAL_OUTLAY_EXPENDITURE        0
# GRADES_ALL_G                    110
# AVG_MATH_4_SCORE                 26
# dtype: int64

# %%
missing_score = df.loc[df['AVG_MATH_4_SCORE'].isnull()]
missing_score.head()
# Out:
#        STATE  YEAR  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 1     ALASKA  1992        1049591           106780         720711
# 13  ILLINOIS  1992        9748650           597077        3073178
# 16    KANSAS  1992        2245348           121625         903199
# 26   MONTANA  1992         828983            69947         337455
# 28    NEVADA  1992        1097076            45018         724032
#
#     LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 1          222100             972488                   498362
# 13        6078395            9850560                  5010400
# 16        1220524            2234915                  1165749
# 26         421581             781009                   412219
# 28         328026            1251651                   572623
#
#     SUPPORT_SERVICES_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE  GRADES_ALL_G  \
# 1                         350902                       37451      122487.0
# ...

# %%
mals = list(missing_score.index)

# %%
df.groupby(['YEAR'])['AVG_MATH_4_SCORE'].mean()
# Out:
# YEAR
# 1992    218.410116
# 1996    221.479509
# 2000    224.803526
# 2003    233.874626
# 2005    237.053410
# 2007    239.147568
# 2009    239.517404
# 2011    240.477019
# 2013    241.891073
# 2015    240.233705
# Name: AVG_MATH_4_SCORE, dtype: float64

# %%
df['AVG_MATH_4_SCORE'].fillna(df.groupby(['YEAR'])['AVG_MATH_4_SCORE'].transform('mean'), inplace=True)

# %%
df.iloc[mals].head(30)
# Out:
#              STATE  YEAR  TOTAL_REVENUE  FEDERAL_REVENUE  STATE_REVENUE  \
# 1           ALASKA  1992        1049591           106780         720711
# 13        ILLINOIS  1992        9748650           597077        3073178
# 16          KANSAS  1992        2245348           121625         903199
# 26         MONTANA  1992         828983            69947         337455
# 28          NEVADA  1992        1097076            45018         724032
# 37          OREGON  1992        2773959           163544         788309
# 41    SOUTH_DAKOTA  1992         551668            60671         147834
# 45         VERMONT  1992         812377            31757         204163
# 47      WASHINGTON  1992        4870832           263053        3467779
# 63           IDAHO  1996        1134052            80486         718218
# 64        ILLINOIS  1996       12732129           728400        4191483
# 67          KANSAS  1996        2914544           140242        1658774
# ...

# %%
df.isnull().sum()
# Out:
# STATE                             0
# YEAR                              0
# TOTAL_REVENUE                     0
# FEDERAL_REVENUE                   0
# STATE_REVENUE                     0
# LOCAL_REVENUE                     0
# TOTAL_EXPENDITURE                 0
# INSTRUCTION_EXPENDITURE           0
# SUPPORT_SERVICES_EXPENDITURE      0
# CAPITAL_OUTLAY_EXPENDITURE        0
# GRADES_ALL_G                    110
# AVG_MATH_4_SCORE                  0
# dtype: int64

# %%
df.groupby(['YEAR'])['AVG_MATH_4_SCORE'].std()
# Out:
# YEAR
# 1992    7.515413
# 1996    7.900349
# 2000    7.404975
# 2003    6.762396
# 2005    6.697912
# 2007    6.778654
# 2009    6.403793
# 2011    5.846239
# 2013    5.508368
# 2015    4.873570
# Name: AVG_MATH_4_SCORE, dtype: float64

# %%
df.groupby(['STATE','YEAR'])['AVG_MATH_4_SCORE'].mean()
# Out:
# STATE          YEAR
# ALABAMA        1992    208.327876
#                1996    211.646973
#                2000    217.941053
#                2003    223.344643
#                2005    225.071236
#                2007    228.520018
#                2009    227.962650
#                2011    231.286019
#                2013    232.861333
#                2015    230.977423
# ALASKA         1992    218.410116
#                1996    223.833455
#                2000    224.803526
#                2003    232.991654
#                2005    235.510706
#                2007    237.273893
#                2009    237.212284
#                2011    236.359658
#                2013    236.122004
#                2015    236.328417
# ARIZONA        1992    215.253932
#                1996    217.575940
#                2000    218.766619
#                2003    228.911396
#                2005    229.800673
#                2007    231.936934
#                2009    229.991105
# ...

# %%
df.groupby(['STATE'])['AVG_MATH_4_SCORE'].max()
# Out:
# STATE
# ALABAMA                 232.861333
# ALASKA                  237.273893
# ARIZONA                 240.304912
# ARKANSAS                239.890522
# CALIFORNIA              234.164993
# COLORADO                246.975708
# CONNECTICUT             244.717743
# DELAWARE                243.107758
# DISTRICT_OF_COLUMBIA    231.307525
# FLORIDA                 242.664321
# GEORGIA                 240.047237
# HAWAII                  243.308619
# IDAHO                   241.650116
# ILLINOIS                239.000204
# INDIANA                 248.596777
# IOWA                    245.793506
# KANSAS                  247.923654
# KENTUCKY                241.727762
# LOUISIANA               234.281902
# MAINE                   245.847002
# MARYLAND                247.106556
# MASSACHUSETTS           253.396456
# MICHIGAN                237.706003
# MINNESOTA               253.420961
# MISSISSIPPI             234.243053
# MISSOURI                240.684381
# ...

# %%
df.groupby(['STATE'])['AVG_MATH_4_SCORE'].min()
# Out:
# STATE
# ALABAMA                 208.327876
# ALASKA                  218.410116
# ARIZONA                 215.253932
# ARKANSAS                210.206028
# CALIFORNIA              208.398961
# COLORADO                221.023429
# CONNECTICUT             226.798480
# DELAWARE                215.025102
# DISTRICT_OF_COLUMBIA    187.134670
# FLORIDA                 213.689751
# GEORGIA                 215.455862
# HAWAII                  214.056666
# IDAHO                   221.479509
# ILLINOIS                218.410116
# INDIANA                 221.037742
# IOWA                    229.126198
# KANSAS                  218.410116
# KENTUCKY                215.048158
# LOUISIANA               204.140211
# MAINE                   230.568646
# MARYLAND                217.317708
# MASSACHUSETTS           226.597918
# MICHIGAN                219.878352
# MINNESOTA               228.493596
# MISSISSIPPI             201.828261
# MISSOURI                222.215600
# ...

# %%
sns.lmplot(x='INSTRUCTION_EXPENDITURE', y='AVG_MATH_4_SCORE', data=df)

# %%
sns.lmplot(x='INSTRUCTION_EXPENDITURE', y='AVG_MATH_4_SCORE', data=df, 
           fit_reg=False) #remove regression line

# %%
sns.lmplot(x='TOTAL_EXPENDITURE', y='AVG_MATH_4_SCORE', data=df)

# %%
sns.lmplot(x='FEDERAL_REVENUE', y='AVG_MATH_4_SCORE', data=df)

# %%
sns.lmplot(x='FEDERAL_REVENUE', y='GRADES_ALL_G', data=df)

# %%
sns.lmplot(x='STATE_REVENUE', y='GRADES_ALL_G', data=df)

# %%
stats_df = df.drop(['STATE', 'YEAR', 'FEDERAL_REVENUE', 'STATE_REVENUE', 'LOCAL_REVENUE', 'GRADES_ALL_G'], axis=1)
stats_df.head()
# Out:
#    TOTAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0        2678885            2653798                  1481703
# 1        1049591             972488                   498362
# 2        3258079            3401580                  1435908
# 3        1711959            1743022                   964323
# 4       26260025           27138832                 14358922
#
#    SUPPORT_SERVICES_EXPENDITURE  CAPITAL_OUTLAY_EXPENDITURE  AVG_MATH_4_SCORE
# 0                        735036                      174053        208.327876
# 1                        350902                       37451        218.410116
# 2                       1007732                      609114        215.253932
# 3                        483488                      145212        210.206028
# 4                       8520926                     2044688        208.398961

# %%
plt.figure(figsize=(12,7))

#show correlation of stats via heatmap
corr = stats_df.corr()

sns.heatmap(corr, vmin=-1, annot=True)

# %%
sns.barplot('YEAR', 'AVG_MATH_4_SCORE', data=df)

# %%
sns.barplot('YEAR', 'TOTAL_REVENUE', data=df)

# %%
sns.barplot('YEAR', 'INSTRUCTION_EXPENDITURE', data=df)
